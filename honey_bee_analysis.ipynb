# %%
import os
from math import pi
import numpy as np
import pandas as pd
import skimage.io as skimg
import skimage.transform as transform
import tensorflow
from bokeh.io import output_file, show
from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource, Range1d, Plot, Title
from bokeh.models.glyphs import ImageURL
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import cumsum
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Dense, Conv2D, Flatten, MaxPool2D, Dropout
from keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn import metrics
from sklearn.model_selection import train_test_split as split

# Settings
np.random.seed(40)
tensorflow.random.set_seed(40)

# %%
# Output File for Bokeh Plots
output_file('honey_bee.html', title='Health of your Bees')

# Plot for loss
plot_loss = figure(title='Loss during Training & Validation')

# Plot for accuracy
plot_acc = figure(title='Accuracy during Training & Validation')

# Global variables
img_dir = './bee_imgs/'
width_img = 100
height_img = 100
channels = 3
print_flag = 1
test_size = 0.1
batch_size = 50
epoch_no = 50

# %%
# Load bee data
bees = pd.read_csv('./bee_data.csv',
                   index_col=False,
                   parse_dates={'datetime': [1, 2]},
                   dtype={'subspecies': 'category', 'health': 'category', 'caste': 'category'})
# Out:
# C:\Users\ishan\AppData\Local\Temp\ipykernel_13808\1237626657.py:2: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   bees = pd.read_csv('./bee_data.csv',
# C:\Users\ishan\AppData\Local\Temp\ipykernel_13808\1237626657.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bees = pd.read_csv('./bee_data.csv',

# %%
def get_image_sizes(file):
    image = skimg.imread(img_dir + file)
    return list(image.shape)

def get_images(file):
    image = skimg.imread(img_dir + file)
    image = transform.resize(image, (width_img, height_img), mode='reflect')
    return image[:, :, :channels]

# %%
def plot_metric(plot, metric):
    plot.line(list(range(1, epoch_no + 1)), hist_metrics[metric], line_color='green', line_width=1,
              legend_label="Training")
    plot.circle(list(range(1, epoch_no + 1)), hist_metrics[metric], fill_color="green", size=8, legend_label="Training")
    plot.line(list(range(1, epoch_no + 1)), hist_metrics['val_' + metric], line_color='red', line_width=1,
              line_dash='dotted', legend_label="Validation")
    plot.circle(list(range(1, epoch_no + 1)), hist_metrics['val_' + metric], fill_color="red", size=8,
                legend_label="Validation")
    plot.legend.location = "top_left"
    plot.legend.click_policy = "hide"
    return plot

# %%
def preprocess(data):
    data.dropna(inplace=True)
    image_plot = plot_imagesize(data['file'])
    bees_with_images = data['file'].apply(lambda file: os.path.exists(img_dir + file))
    return data[bees_with_images], image_plot

def balance(data, field):
    category_count = int(len(data) / data[field].cat.categories.size)
    return data.groupby(field, as_index=False).apply(
        lambda index: index.sample(category_count, replace=True)).reset_index(drop=True)

# %%
def test_accuracy(model, test_X, test_y):
    predicted = model.predict(test_X)
    test_predicted = np.argmax(predicted, axis=1)
    test_truth = np.argmax(test_y.values, axis=1)
    print(metrics.classification_report(test_truth, test_predicted, target_names=test_y.columns))
    test_res = model.evaluate(test_X, test_y.values, verbose=print_flag)
    print('Loss function: %s, accuracy:' % test_res[0], test_res[1])
    category_acc = np.logical_and((predicted > 0.5), test_y).sum() / test_y.sum()
    health = list(category_acc.keys())
    counts = list(category_acc)
    plot = figure(x_range=health, y_range=(0, 1), title='Accuracy for each health', toolbar_location=None, tools="")
    source = ColumnDataSource(data=dict(health=health, counts=counts, color=Spectral6))
    plot.vbar(x='health', top='counts', width=0.9, source=source, legend_label="health", color='color')
    plot.xaxis.visible = False
    plot.legend.orientation = "vertical"
    plot.legend.location = "top_center"
    return plot

# %%
def plot_imagesize(images):
    image_sizes = np.stack(images.apply(get_image_sizes))
    df = pd.DataFrame(image_sizes, columns=['w', 'h', 'c'])
    radii = np.random.random(size=df.shape[0]) * 2.5
    plot = figure(title="Height vs. Width of images", x_range=[0, 300], y_range=[0, 300])
    colors = [
        "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50 + 2 * df['w'], 30 + 2 * df['h'])
    ]
    plot.scatter(df['w'], df['h'], radius=radii,
                 fill_color=colors, fill_alpha=0.6,
                 line_color=None)
    plot.xaxis.axis_label = 'Width'
    plot.yaxis.axis_label = 'Height'
    return plot

# %%
# Splitting and augmentation
bees, image_plot = preprocess(bees)
train_bees, test_bees = split(bees, test_size=test_size)
train_bees, validate_bees = split(train_bees, test_size=test_size)
train_bees = balance(train_bees, 'health')

train_X = np.stack(train_bees['file'].apply(get_images))
validate_X = np.stack(validate_bees['file'].apply(get_images))
test_X = np.stack(test_bees['file'].apply(get_images))

train_y = pd.get_dummies(train_bees['health'])
validate_y = pd.get_dummies(validate_bees['health'])
test_y = pd.get_dummies(test_bees['health'])

# Image data generator for augmentation
imgDG = ImageDataGenerator(
    rotation_range=180,
    zoom_range=0.1,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True)
imgDG.fit(train_X)
# Out:
# BokehDeprecationWarning: 'scatter(radius=...)' was deprecated in Bokeh 3.4.0 and will be removed, use 'circle(radius=...) instead' instead.
# C:\Users\ishan\AppData\Local\Temp\ipykernel_13808\1554256820.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   return data.groupby(field, as_index=False).apply(
# C:\Users\ishan\AppData\Local\Temp\ipykernel_13808\1554256820.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return data.groupby(field, as_index=False).apply(

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_accuracy', patience=20, verbose=print_flag)
save_best = ModelCheckpoint('healthy_model'
                            , monitor='val_accuracy'
                            , verbose=print_flag
                            , save_best_only=True
                            , save_weights_only=True)

# Model definition
model = Sequential()
model.add(Conv2D(16, kernel_size=3, input_shape=(width_img, height_img, 3), activation='relu', padding='same'))
model.add(MaxPool2D(2))
model.add(Dropout(0.2))
model.add(Conv2D(16, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(train_y.columns.size, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
steps = np.round(train_X.shape[0] / batch_size, 0)
history = model.fit(imgDG.flow(train_X, train_y, batch_size=batch_size)
                              , epochs=epoch_no
                              , validation_data=[validate_X, validate_y]
                              , steps_per_epoch=steps
                              , callbacks=[early_stop, save_best])
hist_metrics = history.history
# Out:
# Epoch 1/50
# 84/84 [==============================] - ETA: 0s - loss: 1.5745 - accuracy: 0.3725
# Epoch 1: val_accuracy improved from -inf to 0.59871, saving model to healthy_model
# 84/84 [==============================] - 13s 92ms/step - loss: 1.5745 - accuracy: 0.3725 - val_loss: 1.2376 - val_accuracy: 0.5987
# Epoch 2/50
# 84/84 [==============================] - ETA: 0s - loss: 0.9484 - accuracy: 0.6404
# Epoch 2: val_accuracy improved from 0.59871 to 0.72747, saving model to healthy_model
# 84/84 [==============================] - 7s 86ms/step - loss: 0.9484 - accuracy: 0.6404 - val_loss: 0.7420 - val_accuracy: 0.7275
# Epoch 3/50
# 84/84 [==============================] - ETA: 0s - loss: 0.6991 - accuracy: 0.6965
# Epoch 3: val_accuracy improved from 0.72747 to 0.76395, saving model to healthy_model
# 84/84 [==============================] - 7s 84ms/step - loss: 0.6991 - accuracy: 0.6965 - val_loss: 0.7215 - val_accuracy: 0.7639
# Epoch 4/50
# 84/84 [==============================] - ETA: 0s - loss: 0.5360 - accuracy: 0.7576
# Epoch 4: val_accuracy improved from 0.76395 to 0.78541, saving model to healthy_model
# 84/84 [==============================] - 11s 133ms/step - loss: 0.5360 - accuracy: 0.7576 - val_loss: 0.5160 - val_accuracy: 0.7854
# Epoch 5/50
# 84/84 [==============================] - ETA: 0s - loss: 0.4706 - accuracy: 0.7746
# Epoch 5: val_accuracy improved from 0.78541 to 0.80258, saving model to healthy_model
# 84/84 [==============================] - 18s 215ms/step - loss: 0.4706 - accuracy: 0.7746 - val_loss: 0.4628 - val_accuracy: 0.8026
# Epoch 6/50
# 84/84 [==============================] - ETA: 0s - loss: 0.4326 - accuracy: 0.8035
# Epoch 6: val_accuracy did not improve from 0.80258
# 84/84 [==============================] - 17s 206ms/step - loss: 0.4326 - accuracy: 0.8035 - val_loss: 0.4578 - val_accuracy: 0.8026
# Epoch 7/50
# 84/84 [==============================] - ETA: 0s - loss: 0.4114 - accuracy: 0.7997
# Epoch 7: val_accuracy did not improve from 0.80258
# 84/84 [==============================] - 17s 202ms/step - loss: 0.4114 - accuracy: 0.7997 - val_loss: 0.5651 - val_accuracy: 0.7661
# Epoch 8/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3844 - accuracy: 0.8171
# Epoch 8: val_accuracy improved from 0.80258 to 0.85408, saving model to healthy_model
# 84/84 [==============================] - 17s 196ms/step - loss: 0.3844 - accuracy: 0.8171 - val_loss: 0.3335 - val_accuracy: 0.8541
# Epoch 9/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3942 - accuracy: 0.8135
# Epoch 9: val_accuracy improved from 0.85408 to 0.85837, saving model to healthy_model
# 84/84 [==============================] - 23s 279ms/step - loss: 0.3942 - accuracy: 0.8135 - val_loss: 0.3089 - val_accuracy: 0.8584
# Epoch 10/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3842 - accuracy: 0.8166
# Epoch 10: val_accuracy did not improve from 0.85837
# 84/84 [==============================] - 21s 248ms/step - loss: 0.3842 - accuracy: 0.8166 - val_loss: 0.3735 - val_accuracy: 0.8369
# Epoch 11/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.8298
# Epoch 11: val_accuracy improved from 0.85837 to 0.86695, saving model to healthy_model
# 84/84 [==============================] - 18s 213ms/step - loss: 0.3583 - accuracy: 0.8298 - val_loss: 0.3355 - val_accuracy: 0.8670
# Epoch 12/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3555 - accuracy: 0.8324
# Epoch 12: val_accuracy did not improve from 0.86695
# 84/84 [==============================] - 18s 211ms/step - loss: 0.3555 - accuracy: 0.8324 - val_loss: 0.4145 - val_accuracy: 0.8112
# Epoch 13/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3367 - accuracy: 0.8309
# Epoch 13: val_accuracy did not improve from 0.86695
# 84/84 [==============================] - 18s 215ms/step - loss: 0.3367 - accuracy: 0.8309 - val_loss: 0.3578 - val_accuracy: 0.8476
# Epoch 14/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3181 - accuracy: 0.8489
# Epoch 14: val_accuracy improved from 0.86695 to 0.89914, saving model to healthy_model
# 84/84 [==============================] - 18s 209ms/step - loss: 0.3181 - accuracy: 0.8489 - val_loss: 0.2414 - val_accuracy: 0.8991
# Epoch 15/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3377 - accuracy: 0.8333
# Epoch 15: val_accuracy did not improve from 0.89914
# 84/84 [==============================] - 18s 215ms/step - loss: 0.3377 - accuracy: 0.8333 - val_loss: 0.2354 - val_accuracy: 0.8991
# Epoch 16/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3481 - accuracy: 0.8415
# Epoch 16: val_accuracy did not improve from 0.89914
# 84/84 [==============================] - 18s 210ms/step - loss: 0.3481 - accuracy: 0.8415 - val_loss: 0.3188 - val_accuracy: 0.8605
# Epoch 17/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3129 - accuracy: 0.8517
# Epoch 17: val_accuracy improved from 0.89914 to 0.92489, saving model to healthy_model
# 84/84 [==============================] - 18s 218ms/step - loss: 0.3129 - accuracy: 0.8517 - val_loss: 0.1902 - val_accuracy: 0.9249
# Epoch 18/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3233 - accuracy: 0.8438
# Epoch 18: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 18s 213ms/step - loss: 0.3233 - accuracy: 0.8438 - val_loss: 0.2885 - val_accuracy: 0.8884
# Epoch 19/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3043 - accuracy: 0.8551
# Epoch 19: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 21s 250ms/step - loss: 0.3043 - accuracy: 0.8551 - val_loss: 0.3600 - val_accuracy: 0.8369
# Epoch 20/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.8565
# Epoch 20: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 24s 281ms/step - loss: 0.3019 - accuracy: 0.8565 - val_loss: 0.1855 - val_accuracy: 0.9249
# Epoch 21/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2943 - accuracy: 0.8579
# Epoch 21: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 24s 282ms/step - loss: 0.2943 - accuracy: 0.8579 - val_loss: 0.3464 - val_accuracy: 0.8433
# Epoch 22/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.8658
# Epoch 22: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 21s 250ms/step - loss: 0.2717 - accuracy: 0.8658 - val_loss: 0.2527 - val_accuracy: 0.8927
# Epoch 23/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.8510
# Epoch 23: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 20s 236ms/step - loss: 0.3089 - accuracy: 0.8510 - val_loss: 0.4530 - val_accuracy: 0.8176
# Epoch 24/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.8715
# Epoch 24: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 21s 254ms/step - loss: 0.2693 - accuracy: 0.8715 - val_loss: 0.2217 - val_accuracy: 0.9163
# Epoch 25/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2827 - accuracy: 0.8634
# Epoch 25: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 25s 293ms/step - loss: 0.2827 - accuracy: 0.8634 - val_loss: 0.2953 - val_accuracy: 0.8734
# Epoch 26/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.8684
# Epoch 26: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 20s 238ms/step - loss: 0.2708 - accuracy: 0.8684 - val_loss: 0.2785 - val_accuracy: 0.8863
# Epoch 27/50
# 84/84 [==============================] - ETA: 0s - loss: 0.3002 - accuracy: 0.8539
# Epoch 27: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 20s 242ms/step - loss: 0.3002 - accuracy: 0.8539 - val_loss: 0.3701 - val_accuracy: 0.8455
# Epoch 28/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 0.8637
# Epoch 28: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 18s 213ms/step - loss: 0.2894 - accuracy: 0.8637 - val_loss: 0.2266 - val_accuracy: 0.8970
# Epoch 29/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2710 - accuracy: 0.8751
# Epoch 29: val_accuracy did not improve from 0.92489
# 84/84 [==============================] - 18s 213ms/step - loss: 0.2710 - accuracy: 0.8751 - val_loss: 0.2048 - val_accuracy: 0.9206
# Epoch 30/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.8894
# Epoch 30: val_accuracy improved from 0.92489 to 0.92704, saving model to healthy_model
# 84/84 [==============================] - 18s 209ms/step - loss: 0.2346 - accuracy: 0.8894 - val_loss: 0.1484 - val_accuracy: 0.9270
# Epoch 31/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2575 - accuracy: 0.8823
# Epoch 31: val_accuracy did not improve from 0.92704
# 84/84 [==============================] - 18s 210ms/step - loss: 0.2575 - accuracy: 0.8823 - val_loss: 0.2691 - val_accuracy: 0.8991
# Epoch 32/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.8887
# Epoch 32: val_accuracy did not improve from 0.92704
# 84/84 [==============================] - 18s 211ms/step - loss: 0.2492 - accuracy: 0.8887 - val_loss: 0.3161 - val_accuracy: 0.8884
# Epoch 33/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2619 - accuracy: 0.8809
# Epoch 33: val_accuracy did not improve from 0.92704
# 84/84 [==============================] - 18s 210ms/step - loss: 0.2619 - accuracy: 0.8809 - val_loss: 0.2034 - val_accuracy: 0.9142
# Epoch 34/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2177 - accuracy: 0.8997
# Epoch 34: val_accuracy improved from 0.92704 to 0.93133, saving model to healthy_model
# 84/84 [==============================] - 18s 216ms/step - loss: 0.2177 - accuracy: 0.8997 - val_loss: 0.1647 - val_accuracy: 0.9313
# Epoch 35/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.8904
# Epoch 35: val_accuracy did not improve from 0.93133
# 84/84 [==============================] - 17s 204ms/step - loss: 0.2342 - accuracy: 0.8904 - val_loss: 0.2150 - val_accuracy: 0.9077
# Epoch 36/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2320 - accuracy: 0.8918
# Epoch 36: val_accuracy did not improve from 0.93133
# 84/84 [==============================] - 18s 208ms/step - loss: 0.2320 - accuracy: 0.8918 - val_loss: 0.2759 - val_accuracy: 0.8991
# Epoch 37/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.8909
# Epoch 37: val_accuracy improved from 0.93133 to 0.93348, saving model to healthy_model
# 84/84 [==============================] - 18s 214ms/step - loss: 0.2343 - accuracy: 0.8909 - val_loss: 0.1521 - val_accuracy: 0.9335
# Epoch 38/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2178 - accuracy: 0.8940
# Epoch 38: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 17s 207ms/step - loss: 0.2178 - accuracy: 0.8940 - val_loss: 0.2542 - val_accuracy: 0.8948
# Epoch 39/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2327 - accuracy: 0.8918
# Epoch 39: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 211ms/step - loss: 0.2327 - accuracy: 0.8918 - val_loss: 0.2347 - val_accuracy: 0.8970
# Epoch 40/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.8758
# Epoch 40: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 208ms/step - loss: 0.2683 - accuracy: 0.8758 - val_loss: 0.1607 - val_accuracy: 0.9249
# Epoch 41/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.8947
# Epoch 41: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 216ms/step - loss: 0.2325 - accuracy: 0.8947 - val_loss: 0.3129 - val_accuracy: 0.8755
# Epoch 42/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.8816
# Epoch 42: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 214ms/step - loss: 0.2520 - accuracy: 0.8816 - val_loss: 0.1508 - val_accuracy: 0.9313
# Epoch 43/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.8906
# Epoch 43: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 19s 220ms/step - loss: 0.2325 - accuracy: 0.8906 - val_loss: 0.2080 - val_accuracy: 0.9077
# Epoch 44/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2299 - accuracy: 0.8921
# Epoch 44: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 214ms/step - loss: 0.2299 - accuracy: 0.8921 - val_loss: 0.2600 - val_accuracy: 0.8863
# Epoch 45/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2221 - accuracy: 0.9019
# Epoch 45: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 216ms/step - loss: 0.2221 - accuracy: 0.9019 - val_loss: 0.1929 - val_accuracy: 0.9206
# Epoch 46/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 0.8868
# Epoch 46: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 215ms/step - loss: 0.2357 - accuracy: 0.8868 - val_loss: 0.1721 - val_accuracy: 0.9270
# Epoch 47/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.8897
# Epoch 47: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 214ms/step - loss: 0.2352 - accuracy: 0.8897 - val_loss: 0.1962 - val_accuracy: 0.9163
# Epoch 48/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9021
# Epoch 48: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 214ms/step - loss: 0.2125 - accuracy: 0.9021 - val_loss: 0.2178 - val_accuracy: 0.9034
# Epoch 49/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2246 - accuracy: 0.8992
# Epoch 49: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 18s 210ms/step - loss: 0.2246 - accuracy: 0.8992 - val_loss: 0.1897 - val_accuracy: 0.9335
# Epoch 50/50
# 84/84 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.8949
# Epoch 50: val_accuracy did not improve from 0.93348
# 84/84 [==============================] - 17s 206ms/step - loss: 0.2291 - accuracy: 0.8949 - val_loss: 0.1713 - val_accuracy: 0.9270

# %%
# Plot results
plot_loss = plot_metric(plot_loss, 'loss')
plot_acc = plot_metric(plot_acc, 'accuracy')

# Load best weights
model.load_weights('healthy_model')

# Test accuracy and save model
results = model.evaluate(test_X, test_y.values, verbose=print_flag)
print('Model was created with Loss of ' + str(results[0]) + ' with Accuracy: ' + str(results[1]))
accuracy_plot = test_accuracy(model, test_X, test_y)

# Save model
model.save("new__model.h5")
# Out:
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# 17/17 [==============================] - 0s 13ms/step - loss: 0.1718 - accuracy: 0.9208
# Model was created with Loss of 0.171846404671669 with Accuracy: 0.9208494424819946
# 17/17 [==============================] - 0s 3ms/step
#                             precision    recall  f1-score   support
#
# Varroa, Small Hive Beetles       0.72      0.87      0.79        54
#               ant problems       0.96      1.00      0.98        43
#   few varrao, hive beetles       0.78      0.61      0.69        59
#                    healthy       0.97      0.98      0.97       331
#          hive being robbed       0.93      0.89      0.91        28
#              missing queen       1.00      1.00      1.00         3
#
#                   accuracy                           0.92       518
#                  macro avg       0.89      0.89      0.89       518
#               weighted avg       0.92      0.92      0.92       518
#
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1718 - accuracy: 0.9208
# Loss function: 0.171846404671669, accuracy: 0.9208494424819946

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (4.44.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.115.0)
# Requirement already satisfied: ffmpy in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.3.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.24.6)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (3.8.4)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (2.9.2)
# Requirement already satisfied: pydub in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.0.10)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.6.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio) (0.30.6)
# Requirement already satisfied: fsspec in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio-client==1.3.0->gradio) (2024.3.1)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from fastapi<1.0->gradio) (0.38.6)
# Requirement already satisfied: certifi in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib~=3.0->gradio) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from pydantic>=2.0->gradio) (2.23.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.8.1)
# Requirement already satisfied: colorama in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ishan\anaconda3\envs\tensorflow\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr
import numpy as np
from tensorflow.keras.models import load_model
import skimage.io as skimg
import skimage.transform as transform

# Load the trained model
model = load_model("new__model.h5")

# Define image preprocessing for the model input
def preprocess_image(image):
    image = transform.resize(image, (width_img, height_img), mode='reflect')
    return image[:, :, :channels].reshape(1, width_img, height_img, channels)

# Define the prediction function
def classify_bee_health(image):
    # Preprocess the image
    processed_image = preprocess_image(image)
    
    # Predict the class probabilities
    prediction = model.predict(processed_image)
    
    # Get the predicted class label
    class_index = np.argmax(prediction, axis=1)[0]
    class_labels = train_y.columns  # Assuming train_y columns contain class names
    predicted_class = class_labels[class_index]
    
    return f"The bee's health status is: {predicted_class}"

# Create Gradio Interface
interface = gr.Interface(
    fn=classify_bee_health,
    inputs=gr.Image(type="numpy"),
    outputs="text",
    title="Bee Health Classification",
    description="Upload an image of a bee to determine its health status."
)

# Launch the interface
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\Users\ishan\anaconda3\envs\Tensorflow\lib\site-packages\gradio\analytics.py:106: UserWarning: IMPORTANT: You are using gradio version 4.44.0, however version 4.44.1 is available, please upgrade.
# --------
#   warnings.warn(
# Traceback (most recent call last):
#   File "c:\Users\ishan\anaconda3\envs\Tensorflow\lib\site-packages\gradio\queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#   File "c:\Users\ishan\anaconda3\envs\Tensorflow\lib\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "c:\Users\ishan\anaconda3\envs\Tensorflow\lib\site-packages\gradio\blocks.py", line 1935, in process_api
#     result = await self.call_function(
#   File "c:\Users\ishan\anaconda3\envs\Tensorflow\lib\site-packages\gradio\blocks.py", line 1520, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "c:\Users\ishan\anaconda3\envs\Tensorflow\lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "c:\Users\ishan\anaconda3\envs\Tensorflow\lib\site-packages\anyio\_backends\_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#   File "c:\Users\ishan\anaconda3\envs\Tensorflow\lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#   File "c:\Users\ishan\anaconda3\envs\Tensorflow\lib\site-packages\gradio\utils.py", line 826, in wrapper
#     response = f(*args, **kwargs)
#   File "C:\Users\ishan\AppData\Local\Temp\ipykernel_15996\1414948526.py", line 18, in classify_bee_health
#     processed_image = preprocess_image(image)
#   File "C:\Users\ishan\AppData\Local\Temp\ipykernel_15996\1414948526.py", line 12, in preprocess_image
#     image = transform.resize(image, (width_img, height_img), mode='reflect')
# NameError: name 'width_img' is not defined
